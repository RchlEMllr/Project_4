# %%
 # Import our dependencies
import pandas as pd
from pathlib import Path

# %%
mt_file_path = Path(".\Resources\murder_target.csv")
crime_df = pd.read_csv(mt_file_path, encoding='cp1252')
crime_df
# Out:
#         offense_code  offense_code_extension              offense_type_id  \
# 0               2999                       0      criminal-mischief-other
# 1               2999                       0      criminal-mischief-other
# 2               2999                       0      criminal-mischief-other
# 3               2999                       0      criminal-mischief-other
# 4               2999                       0      criminal-mischief-other
# ...              ...                     ...                          ...
# 386973          2699                       1      failure-to-pay-cab-fare
# 386974          2699                       2               theft-of-meals
# 386975          2701                       0        embezzle-bus-property
# 386976          2801                       0      stolen-property-sale-of
# 386977          2804                       0  outside-steal-recovered-veh
#
#        offense_category_id          reported_date     incident_address  \
# ...

# %%
crime_df.isna().sum()
# Out:
# offense_code                  0
# offense_code_extension        0
# offense_type_id               0
# offense_category_id           0
# reported_date               113
# incident_address          15616
# geo_lon                   15882
# geo_lat                   15882
# district_id                 170
# precinct_id                 113
# neighborhood_id             802
# victim_count                113
# offense_type_name             0
# murders                       0
# dtype: int64

# %%
crime_na_df = crime_df.dropna()

# %%
crime_na_df.isna().sum()
# Out:
# offense_code              0
# offense_code_extension    0
# offense_type_id           0
# offense_category_id       0
# reported_date             0
# incident_address          0
# geo_lon                   0
# geo_lat                   0
# district_id               0
# precinct_id               0
# neighborhood_id           0
# victim_count              0
# offense_type_name         0
# murders                   0
# dtype: int64

# %%
crime_na_df
# Out:
#         offense_code  offense_code_extension          offense_type_id  \
# 0               2999                       0  criminal-mischief-other
# 1               2999                       0  criminal-mischief-other
# 2               2999                       0  criminal-mischief-other
# 3               2999                       0  criminal-mischief-other
# 4               2999                       0  criminal-mischief-other
# ...              ...                     ...                      ...
# 386860          1315                       6           agg-aslt-shoot
# 386861          1315                       6           agg-aslt-shoot
# 386862          1315                       6           agg-aslt-shoot
# 386863          1315                       6           agg-aslt-shoot
# 386864          7099                       5    homicide-accessory-to
#
#        offense_category_id          reported_date          incident_address  \
# ...

# %%
crime_na_df['precinct_id'].value_counts()
# Out:
# precinct_id
# 611.0    25062
# 612.0    18723
# 311.0    16686
# 621.0    15318
# 323.0    13167
# 623.0    13032
# 512.0    11949
# 211.0    11945
# 122.0    11208
# 123.0    11131
# 322.0    10784
# 522.0    10472
# 622.0    10462
# 412.0    10191
# 313.0    10028
# 223.0     9946
# 423.0     9881
# 321.0     9809
# 113.0     9676
# 121.0     9273
# 759.0     9079
# 111.0     8955
# 312.0     8708
# 521.0     8685
# 422.0     8221
# 221.0     8172
# 222.0     7980
# 324.0     7889
# 511.0     7638
# 421.0     7607
# 411.0     7390
# 212.0     7021
# 213.0     6775
# 314.0     6568
# 112.0     6243
# 523.0     4814
# 999.0      175
# 316.0        1
# 232.0        1
# 532.0        1
# Name: count, dtype: int64

# %%
crime_na_df = crime_na_df.loc[crime_na_df['precinct_id'] != 999]
crime_na_df = crime_na_df.loc[crime_na_df['precinct_id'] != 316]
crime_na_df = crime_na_df.loc[crime_na_df['precinct_id'] != 232]
crime_na_df = crime_na_df.loc[crime_na_df['precinct_id'] != 532]
crime_na_df['precinct_id'].value_counts()
# Out:
# precinct_id
# 611.0    25062
# 612.0    18723
# 311.0    16686
# 621.0    15318
# 323.0    13167
# 623.0    13032
# 512.0    11949
# 211.0    11945
# 122.0    11208
# 123.0    11131
# 322.0    10784
# 522.0    10472
# 622.0    10462
# 412.0    10191
# 313.0    10028
# 223.0     9946
# 423.0     9881
# 321.0     9809
# 113.0     9676
# 121.0     9273
# 759.0     9079
# 111.0     8955
# 312.0     8708
# 521.0     8685
# 422.0     8221
# 221.0     8172
# 222.0     7980
# 324.0     7889
# 511.0     7638
# 421.0     7607
# 411.0     7390
# 212.0     7021
# 213.0     6775
# 314.0     6568
# 112.0     6243
# 523.0     4814
# Name: count, dtype: int64

# %%
crime_na_df['reported_date'].value_counts()
# Out:
# reported_date
# 6/24/2020 10:12:00 AM    16
# 5/29/2020 7:00:00 AM     10
# 6/1/2020 12:30:00 AM     10
# 3/8/2021 1:30:00 PM       9
# 5/31/2020 10:30:00 PM     9
#                          ..
# 11/16/2020 5:17:00 PM     1
# 10/17/2018 6:30:00 PM     1
# 2/28/2020 3:41:00 AM      1
# 2/8/2018 8:02:00 PM       1
# 10/2/2023 6:16:00 PM      1
# Name: count, Length: 323759, dtype: int64

# %%
crime_na_df['reported_date'] = pd.to_datetime(crime_na_df['reported_date'])

# %%
crimes_2019_df = crime_na_df[crime_na_df['reported_date'].dt.year == 2019]

# %%
crimes_2019_df = crimes_2019_df.reset_index()
crimes_2019_df
# Out:
#        level_0   index  offense_code  offense_code_extension  \
# 0           11      11          2999                       0
# 1           15      15          2999                       0
# 2           29      29          2999                       0
# 3           32      32          2999                       0
# 4           33      33          2999                       0
# ...        ...     ...           ...                     ...
# 54638   369662  386039          2803                       0
# 54639   369664  386041          2803                       0
# 54640   369670  386047          2803                       0
# 54641   369677  386054          2803                       0
# 54642   369679  386056          2803                       0
#
#                     offense_type_id offense_category_id       reported_date  \
# 0           criminal-mischief-other     public-disorder 2019-08-12 00:28:00
# 1           criminal-mischief-other     public-disorder 2019-09-17 17:52:00
# ...

# %%
crimes_2019_df = crimes_2019_df.drop(columns=['level_0', 'index'])
crimes_2019_df
# Out:
#        offense_code  offense_code_extension               offense_type_id  \
# 0              2999                       0       criminal-mischief-other
# 1              2999                       0       criminal-mischief-other
# 2              2999                       0       criminal-mischief-other
# 3              2999                       0       criminal-mischief-other
# 4              2999                       0       criminal-mischief-other
# ...             ...                     ...                           ...
# 54638          2803                       0  stolen-property-buy-sell-rec
# 54639          2803                       0  stolen-property-buy-sell-rec
# 54640          2803                       0  stolen-property-buy-sell-rec
# 54641          2803                       0  stolen-property-buy-sell-rec
# 54642          2803                       0  stolen-property-buy-sell-rec
#
#       offense_category_id       reported_date              incident_address  \
# ...

# %%
narrow_crimes_2019_df = crimes_2019_df.drop(columns=['offense_code','offense_code_extension','offense_type_id'])
narrow_crimes_2019_df
# Out:
#       offense_category_id       reported_date              incident_address  \
# 0         public-disorder 2019-08-12 00:28:00                   200 16TH ST
# 1         public-disorder 2019-09-17 17:52:00               18635 E 43RD PL
# 2         public-disorder 2019-07-22 12:17:00              4778 N PEORIA ST
# 3         public-disorder 2019-08-21 13:05:00            14558 E ANDREWS DR
# 4         public-disorder 2019-08-11 03:25:00               4407 W OHIO AVE
# ...                   ...                 ...                           ...
# 54638    all-other-crimes 2019-11-13 16:15:00           1700 BLK WEWATTA ST
# 54639    all-other-crimes 2019-02-12 13:20:00     W DAKOTA AVE / S ELIOT ST
# 54640    all-other-crimes 2019-08-15 16:18:00       N GENEVA ST / E 28TH PL
# 54641    all-other-crimes 2019-09-18 14:18:00  1400 BLK TREMONT COURT ALLEY
# 54642    all-other-crimes 2019-10-24 14:22:00         3300 BLK N DOWNING ST
#
#           geo_lon    geo_lat district_id  precinct_id  \
# ...

# %%
narrow_crimes_2019_df = crimes_2019_df.drop(columns=['incident_address','geo_lat','geo_lon','offense_code',
                                                     'offense_code_extension','offense_type_id'])
narrow_crimes_2019_df
# Out:
#       offense_category_id       reported_date district_id  precinct_id  \
# 0         public-disorder 2019-08-12 00:28:00           6        611.0
# 1         public-disorder 2019-09-17 17:52:00           5        523.0
# 2         public-disorder 2019-07-22 12:17:00           5        521.0
# 3         public-disorder 2019-08-21 13:05:00           5        521.0
# 4         public-disorder 2019-08-11 03:25:00           4        412.0
# ...                   ...                 ...         ...          ...
# 54638    all-other-crimes 2019-11-13 16:15:00           6        612.0
# 54639    all-other-crimes 2019-02-12 13:20:00           4        412.0
# 54640    all-other-crimes 2019-08-15 16:18:00           5        512.0
# 54641    all-other-crimes 2019-09-18 14:18:00           1        123.0
# 54642    all-other-crimes 2019-10-24 14:22:00           2        211.0
#
#                   neighborhood_id  victim_count  \
# 0                             cbd           1.0
# ...

# %%
narrow_crimes_2019_df.to_csv('.\Resources\crimes_trimmed.csv', index=False)

# %%
narrow_crimes_2019_df.to_csv('.\Resources\narrow_crimes_2019.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 narrow_crimes_2019_df.to_csv('.\Resources\narrow_crimes_2019.csv', index=False)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
# ...

# %%
narrow_crimes_2019_df.to_csv('.\Resources\narrow_crimes_2019.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 narrow_crimes_2019_df.to_csv('.\Resources\narrow_crimes_2019.csv', index=False)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
# ...
